# %%
import requests
from bs4 import BeautifulSoup as bs
import pymongo
import  re

headers = {'accept': '*/*',
           'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.129 Safari/537.36'}
f = open('connect_string.txt', 'r')
connect = f.read().split(":")
f.close()
db_address = connect[0]
db_port = int(connect[1])
db_name = 'avito_parse_data'
coll_name = 'raw_data'

# %%
def avito_parse(base_url, header):
    jobs_loc = []
    page_counter = 1
    session = requests.Session()
    request = session.get(base_url, headers=header)
    if request.status_code == 200:
        while True:
            soup = bs(request.content, 'html.parser')
            divs = soup.find_all('div', attrs={'class': 'snippet-horizontal item item_table clearfix js-catalog-item-enum item-with-contact js-item-extended'})
            for div in divs:
                title = (div.find('a', attrs={'class': 'snippet-link'}).text).split(",")
                rooms_number = title[0]
                footage = title[1]
                floor = title[2]
                price = (div.find('span', attrs={'data-marker': 'item-price'}).text).replace("\n ","")
                address = (div.find('span', attrs={'class': 'item-address__string'}).text).replace("\n ","")
                metro = div.find('span', attrs={'class': 'item-address-georeferences-item__content'})
                if metro == None:
                    metro = ''
                else:
                    metro = (div.find('span', attrs={'class': 'item-address-georeferences-item__content'}).text).replace("\n ","")
                property_type = "flat"
                all_txt = [rooms_number, footage, floor, price, metro, address, property_type]
                jobs_loc.append(all_txt)

            nextPage = soup.find("span", {"data-marker": "pagination-button/next"})
            if str(nextPage).find("readonly") == -1:
                page_counter += 1
                base_url = url_base + "&p=" + str(page_counter)
                request = session.get(base_url, headers=header)
            else:
                break
        return jobs_loc
    else:
        print('error')

# %%
url_base = 'https://www.avito.ru/moskva/kvartiry/prodam-ASgBAgICAUSSA8YQ?metro=125&q=4-к+квартира'
url = url_base #+ 'search/vacancy?area=' + search_area + '&clusters=true&enable_snippets=true&search_period=' + search_period + '&text=' + search_value + '&page=0'  # area=1317 - Пермский край, search_period=30 - период просмотра, page=0 - Номер страницы
advert = [] 
advert = avito_parse(url, headers)

# %%
advert
# Out:
# [['4-к квартира',
#   ' 213 м²',
#   ' 4/8 эт.',
#   '61 000 000  ₽ ',
#   'Тушинская',
#   'Москва, Ленинградское шоссе, 37к1',
#   'flat'],
#  ['4-к квартира',
#   ' 123 м²',
#   ' 24/24 эт.',
#   '25 743 900  ₽ ',
#   'Тушинская',
#   'ш. Волоколамское, корп. 10, вл. 71/13',
#   'flat'],
#  ['4-к квартира',
#   ' 220 м²',
#   ' 10/30 эт.',
#   '64 900 000  ₽ ',
#   'Тушинская',
#   'Москва, Авиационная улица, 79Б',
#   'flat'],
#  ['4-к квартира',
#   ' 120.6 м²',
#   ' 24/24 эт.',
#   '23 987 340  ₽ ',
#   'Тушинская',
#   'ш. Волоколамское, корп. 10, вл. 71/13',
#   'flat'],
#  ['4-к квартира',
#   ' 160 м²',
#   ' 29/29 эт.',
#   '53 000 000  ₽ ',
#   'Тушинская',
#   'Москва, улица Маршала Катукова',
#   'flat'],
#  ['4-к квартира',
#   ' 113 м²',
#   ' 11/21 эт.',
#   '20 000 000  ₽ ',
#   'Тушинская',
#   'Волоколамский пр.',
#   'flat'],
#  ['4-к квартира',
#   ' 200 м²',
#   ' 4/10 эт.',
#   '93 660 000  ₽ ',
#   'Тушинская',
#   'Москва, Ленинградское шоссе, 37к1',
#   'flat'],
#  ['4-к квартира',
#   ' 105 м²',
#   ' 2/5 эт.',
#   '17 950 000  ₽ ',
#   'Тушинская',
#   'Москва, улица Свободы, 3',
#   'flat'],
#  ['4-к квартира',
#   ' 142 м²',
#   ' 6/7 эт.',
#   '25 000 000  ₽ ',
#   'Тушинская',
#   'Москва, проезд Стратонавтов, 11к1',
#   'flat'],
#  ['4-к квартира',
#   ' 226.6 м²',
#   ' 5/32 эт.',
#   '50 000 000  ₽ ',
#   'Тушинская',
#   'Авиационная ул., 77к2',
#   'flat'],
#  ['4-к квартира',
#   ' 102 м²',
#   ' 10/12 эт.',
#   '20 900 000  ₽ ',
#   'Тушинская',
#   'ул. Фабрициуса, 18к1',
#   'flat'],
#  ['4-к квартира',
#   ' 160 м²',
#   ' 5/6 эт.',
#   '99 000 000  ₽ ',
#   'Тушинская',
#   'Москва, Береговая улица, 4к2',
#   'flat'],
#  ['4-к квартира',
#   ' 136.4 м²',
#   ' 9/16 эт.',
#   '26 500 000  ₽ ',
#   'Тушинская',
#   'Москва, бульвар Яна Райниса, 31',
#   'flat'],
#  ['4-к квартира',
#   ' 189 м²',
#   ' 5/23 эт.',
#   '146 369 965  ₽ ',
#   'Тушинская',
#   'Москва, Иваньковское шоссе, 5',
#   'flat'],
#  ['4-к квартира',
#   ' 188 м²',
#   ' 19/30 эт.',
#   '70 000 000  ₽ ',
#   'Тушинская',
#   'Москва, Авиационная улица, 79Б',
#   'flat'],
#  ['4-к квартира',
#   ' 104.4 м²',
#   ' 13/14 эт.',
#   '23 000 000  ₽ ',
#   'Тушинская',
#   'Большая Набережная ул., 11к3',
#   'flat'],
#  ['4-к квартира',
#   ' 112.5 м²',
#   ' 20/21 эт.',
#   '20 816 200  ₽ ',
#   'Тушинская',
#   'ул. Летняя, вл. 95Б',
#   'flat'],
#  ['4-к квартира',
#   ' 176 м²',
#   ' 29/34 эт.',
#   '67 500 000  ₽ ',
#   'Тушинская',
#   'Авиационная ул., 77',
#   'flat'],
#  ['1-к квартира',
#   ' 51 м²',
#   ' 4/5 эт.',
#   '10 500 000  ₽ ',
#   'Тушинская',
#   'ул Подмосковная, 7',
#   'flat'],
#  ['6-к квартира',
#   ' 402 м²',
#   ' 1/4 эт.',
#   '296 000 000  ₽ ',
#   'Тушинская',
#   'Москва, Береговая улица',
#   'flat'],
#  ['4-к квартира',
#   ' 120 м²',
#   ' 12/12 эт.',
#   '31 000 000  ₽ ',
#   'Тушинская',
#   'Нелидовская ул., 23к2',
#   'flat'],
#  ['6-к квартира',
#   ' 354.1 м²',
#   ' 5/6 эт.',
#   '214 600 000  ₽ ',
#   'Тушинская',
#   'Москва, Ленинградское шоссе, 37к1',
#   'flat'],
#  ['4-к квартира',
#   ' 152 м²',
#   ' 3/17 эт.',
#   '34 800 000  ₽ ',
#   'Тушинская',
#   'Лодочная ул., 17',
#   'flat'],
#  ['4-к квартира',
#   ' 99.6 м²',
#   ' 11/22 эт.',
#   '16 747 000  ₽ ',
#   'Тушинская',
#   'Москва, Светлогорский проезд, 3',
#   'flat'],
#  ['4-к квартира',
#   ' 144.7 м²',
#   ' 11/16 эт.',
#   '26 767 600  ₽ ',
#   'Тушинская',
#   'б-р Яна Райниса, 31',
#   'flat'],
#  ['4-к квартира',
#   ' 171.4 м²',
#   ' 3/3 эт.',
#   '87 550 000  ₽ ',
#   'Тушинская',
#   'Москва, Ленинградское шоссе, 23к1',
#   'flat'],
#  ['4-к квартира',
#   ' 190 м²',
#   ' 1/6 эт.',
#   '64 000 000  ₽ ',
#   'Тушинская',
#   'Москва, Береговая улица, 4к10',
#   'flat'],
#  ['4-к квартира',
#   ' 126 м²',
#   ' 40/40 эт.',
#   '42 000 000  ₽ ',
#   'Тушинская',
#   'Москва, Авиационная улица, 79В',
#   'flat'],
#  ['4-к квартира',
#   ' 150.3 м²',
#   ' 8/30 эт.',
#   '34 900 000  ₽ ',
#   'Тушинская',
#   'Авиационная ул., 79Б',
#   'flat'],
#  ['1-к квартира',
#   ' 32.8 м²',
#   ' 4/9 эт.',
#   '7 899 000  ₽ ',
#   'Тушинская',
#   'ул. Героев Панфиловцев, 1к5',
#   'flat'],
#  ['3-к квартира',
#   ' 83.4 м²',
#   ' 2/5 эт.',
#   '14 300 000  ₽ ',
#   'Тушинская',
#   'Подмосковная ул., 5',
#   'flat'],
#  ['2-к квартира',
#   ' 72.2 м²',
#   ' 15/20 эт.',
#   '11 100 000  ₽ ',
#   'Тушинская',
#   'Волоколамское ш., вл. 71/8',
#   'flat'],
#  ['2-к квартира',
#   ' 66.9 м²',
#   ' 8/20 эт.',
#   '10 800 000  ₽ ',
#   'Тушинская',
#   'Волоколамское ш., вл. 71/8',
#   'flat'],
#  ['1-к квартира',
#   ' 28.2 м²',
#   ' 4/22 эт.',
#   '5 660 586  ₽ ',
#   'Тушинская',
#   'ш. Волоколамское, вл. 71/22',
#   'flat'],
#  ['4-к квартира',
#   ' 223 м²',
#   ' 4/11 эт.',
#   '93 660 000  ₽ ',
#   'Тушинская',
#   'Москва, Ленинградское шоссе, 37к1',
#   'flat'],
#  ['4-к квартира',
#   ' 98.1 м²',
#   ' 9/25 эт.',
#   '17 500 000  ₽ ',
#   'Тушинская',
#   'Волоколамское ш., 81к2',
#   'flat'],
#  ['1-к квартира',
#   ' 41.8 м²',
#   ' 11/13 эт.',
#   '9 823 000  ₽ ',
#   'Тушинская',
#   'ш. Волоколамское, корп. 10, вл. 71/13',
#   'flat'],
#  ['1-к квартира',
#   ' 34.6 м²',
#   ' 10/22 эт.',
#   '6 201 358  ₽ ',
#   'Тушинская',
#   'ш. Волоколамское, вл. 71/22',
#   'flat'],
#  ['6-к квартира',
#   ' 440 м²',
#   ' 1/4 эт.',
#   '199 000 000  ₽ ',
#   'Тушинская',
#   'Москва, Береговая улица',
#   'flat'],
#  ['4-к квартира',
#   ' 101.9 м²',
#   ' 12/12 эт.',
#   '20 837 600  ₽ ',
#   'Тушинская',
#   'Москва, улица Фабрициуса, 18',
#   'flat'],
#  ['5-к квартира',
#   ' 420 м²',
#   ' 3/4 эт.',
#   '218 178 900  ₽ ',
#   'Тушинская',
#   'Москва, Береговая улица, 4к8',
#   'flat'],
#  ['7-к квартира',
#   ' 367 м²',
#   ' 1/3 эт.',
#   '509 084 100  ₽ ',
#   'Тушинская',
#   'Москва, Береговая улица, 4к6',
#   'flat'],
#  ['4-к квартира',
#   ' 208.4 м²',
#   ' 11/17 эт.',
#   '47 000 000  ₽ ',
#   'Тушинская',
#   'ул. Маршала Василевского, 13к3',
#   'flat'],
#  ['6-к квартира',
#   ' 811 м²',
#   ' 23/24 эт.',
#   '399 994 650  ₽ ',
#   'Тушинская',
#   'Москва, Иваньковское шоссе, 5',
#   'flat'],
#  ['3-к квартира',
#   ' 66.8 м²',
#   ' 5/12 эт.',
#   '12 700 000  ₽ ',
#   'Тушинская',
#   'ул. Маршала Катукова, 4к1',
#   'flat'],
#  ['2-к квартира',
#   ' 35.4 м²',
#   ' 2/22 эт.',
#   '6 425 100  ₽ ',
#   'Тушинская',
#   'ш. Волоколамское, вл. 71/22',
#   'flat'],
#  ['3-к квартира',
#   ' 77 м²',
#   ' 2/22 эт.',
#   '10 334 940  ₽ ',
#   'Тушинская',
#   'ш. Волоколамское, вл. 71/22',
#   'flat'],
#  ['4-к квартира',
#   ' 136.4 м²',
#   ' 9/16 эт.',
#   '26 500 000  ₽ ',
#   'Тушинская',
#   'Москва, бульвар Яна Райниса, 31',
#   'flat'],
#  ['2-к квартира',
#   ' 60 м²',
#   ' 4/4 эт.',
#   '10 900 000  ₽ ',
#   'Тушинская',
#   'Москва, Нелидовская улица, 16',
#   'flat'],
#  ['3-к квартира',
#   ' 70 м²',
#   ' 2/12 эт.',
#   '12 200 000  ₽ ',
#   'Тушинская',
#   '1-й Тушинский пр., 4',
#   'flat'],
#  ['3-к квартира',
#   ' 176 м²',
#   ' 33/40 эт.',
#   '48 000 000  ₽ ',
#   'Тушинская',
#   'Москва, Авиационная улица, 79к1',
#   'flat'],
#  ['1-к квартира',
#   ' 37.8 м²',
#   ' 2/17 эт.',
#   '7 700 000  ₽ ',
#   'Тушинская',
#   'Москва, улица Маршала Катукова, 19к1',
#   'flat'],
#  ['4-к квартира',
#   ' 152 м²',
#   ' 3/25 эт.',
#   '36 799 000  ₽ ',
#   'Тушинская',
#   'Москва, Лодочная улица, 17',
#   'flat'],
#  ['4-к квартира',
#   ' 104 м²',
#   ' 5/5 эт.',
#   '15 000 000  ₽ ',
#   'Тушинская',
#   'ул. Свободы, 3',
#   'flat'],
#  ['4-к квартира',
#   ' 91.9 м²',
#   ' 4/4 эт.',
#   '17 500 000  ₽ ',
#   'Тушинская',
#   'Москва, Сходненская улица, 46/14',
#   'flat'],
#  ['1-к квартира',
#   ' 43 м²',
#   ' 3/12 эт.',
#   '8 990 000  ₽ ',
#   'Тушинская',
#   'Туристская ул., 17',
#   'flat'],
#  ['4-к квартира',
#   ' 205 м²',
#   ' 21/30 эт.',
#   '62 000 000  ₽ ',
#   'Тушинская',
#   'Москва, Авиационная улица, 77к2',
#   'flat'],
#  ['1-к квартира',
#   ' 39 м²',
#   ' 16/17 эт.',
#   '10 700 000  ₽ ',
#   'Тушинская',
#   'Авиационная ул., 72к1',
#   'flat'],
#  ['4-к квартира',
#   ' 98.1 м²',
#   ' 9/25 эт.',
#   '17 500 000  ₽ ',
#   'Тушинская',
#   'Волоколамское ш., 81к2с6',
#   'flat'],
#  ['4-к квартира',
#   ' 189 м²',
#   ' 12/22 эт.',
#   '99 000 000  ₽ ',
#   'Тушинская',
#   'Москва, Авиационная улица, 79Б',
#   'flat'],
#  ['4-к квартира',
#   ' 115.8 м²',
#   ' 15/20 эт.',
#   '22 465 200  ₽ ',
#   'Тушинская',
#   'ул. Циолковского, д. 7',
#   'flat'],
#  ['4-к квартира',
#   ' 101 м²',
#   ' 13/22 эт.',
#   '21 000 000  ₽ ',
#   'Тушинская',
#   'Туристская ул., 10к1',
#   'flat'],
#  ['4-к квартира',
#   ' 77.6 м²',
#   ' 3/4 эт.',
#   '12 450 000  ₽ ',
#   'Тушинская',
#   'ул. Фабрициуса, 38к1',
#   'flat'],
#  ['1-к квартира',
#   ' 31.6 м²',
#   ' 4/5 эт.',
#   '6 800 000  ₽ ',
#   'Тушинская',
#   'Москва, Химкинский бульвар, 13',
#   'flat'],
#  ['4-к квартира',
#   ' 166.4 м²',
#   ' 2/6 эт.',
#   '65 000 000  ₽ ',
#   'Тушинская',
#   'Береговая ул., 4к5',
#   'flat'],
#  ['1-к квартира',
#   ' 29.5 м²',
#   ' 3/4 эт.',
#   '3 540 000  ₽ ',
#   'Тушинская',
#   'Москва, Строительный проезд, 2с1',
#   'flat'],
#  ['4-к квартира',
#   ' 83.8 м²',
#   ' 17/34 эт.',
#   '21 000 000  ₽ ',
#   'Тушинская',
#   'Москва, Авиационная улица, 66',
#   'flat'],
#  ['5-к квартира',
#   ' 255 м²',
#   ' 1/3 эт.',
#   '145 000 000  ₽ ',
#   'Тушинская',
#   'Москва, Ленинградское шоссе, 23к3с2',
#   'flat'],
#  ['3-к квартира',
#   ' 73 м²',
#   ' 8/14 эт.',
#   '14 800 000  ₽ ',
#   'Тушинская',
#   'ул. Свободы, 42',
#   'flat'],
#  ['4-к квартира',
#   ' 83.8 м²',
#   ' 19/34 эт.',
#   '22 000 000  ₽ ',
#   'Тушинская',
#   'Авиационная ул., 66',
#   'flat'],
#  ['1-к квартира',
#   ' 38.4 м²',
#   ' 11/17 эт.',
#   '7 000 000  ₽ ',
#   'Тушинская',
#   'Москва, улица Василия Петушкова, 15',
#   'flat'],
#  ['1-к квартира',
#   ' 38.4 м²',
#   ' 4/22 эт.',
#   '9 408 058  ₽ ',
#   'Тушинская',
#   'Москва, Волоколамское шоссе, 71к4',
#   'flat'],
#  ['5-к квартира',
#   ' 141.9 м²',
#   ' 14/22 эт.',
#   '27 032 659  ₽ ',
#   'Тушинская',
#   'Москва, Волоколамское шоссе, 71к1',
#   'flat'],
#  ['4-к квартира',
#   ' 126.5 м²',
#   ' 16/17 эт.',
#   '22 643 500  ₽ ',
#   'Тушинская',
#   'ул. Циолковского, д. 7',
#   'flat'],
#  ['6-к квартира',
#   ' 241.9 м²',
#   ' 2/6 эт.',
#   '158 000 000  ₽ ',
#   'Тушинская',
#   'Береговая ул., 4к4',
#   'flat'],
#  ['4-к квартира',
#   ' 127 м²',
#   ' 10/17 эт.',
#   '22 733 000  ₽ ',
#   'Тушинская',
#   'ул. Циолковского, д. 7',
#   'flat'],
#  ['4-к квартира',
#   ' 125.1 м²',
#   ' 3/18 эт.',
#   '25 645 500  ₽ ',
#   'Тушинская',
#   'ул. Циолковского, д. 7',
#   'flat'],
#  ['4-к квартира',
#   ' 125.8 м²',
#   ' 14/14 эт.',
#   '28 430 800  ₽ ',
#   'Тушинская',
#   'ул. Циолковского, д. 7',
#   'flat'],
#  ['2-к квартира',
#   ' 34.2 м²',
#   ' 3/5 эт.',
#   '6 999 000  ₽ ',
#   'Тушинская',
#   'Сосновая аллея, 6',
#   'flat'],
#  ['1-к квартира',
#   ' 38.4 м²',
#   ' 4/22 эт.',
#   '9 408 059  ₽ ',
#   'Тушинская',
#   'Волоколамское ш., вл. 71/9',
#   'flat'],
#  ['5-к квартира',
#   ' 242 м²',
#   ' 2/7 эт.',
#   '135 000 000  ₽ ',
#   'Тушинская',
#   'Москва, Береговая улица, 4к5',
#   'flat'],
#  ['1-к квартира',
#   ' 34.4 м²',
#   ' 21/22 эт.',
#   '6 354 712  ₽ ',
#   'Тушинская',
#   'ш. Волоколамское, вл. 71/22',
#   'flat'],
#  ['3-к квартира',
#   ' 124 м²',
#   ' 4/4 эт.',
#   '52 500 000  ₽ ',
#   'Тушинская',
#   'Россия, Москва, метро Балтийская, Береговая улица, 8к1',
#   'flat'],
#  ['1-к квартира',
#   ' 35 м²',
#   ' 14/14 эт.',
#   '7 249 000  ₽ ',
#   'Тушинская',
#   'Москва, проезд Стратонавтов, 10с1',
#   'flat'],
#  ['Студия',
#   ' 26.9 м²',
#   ' 3/22 эт.',
#   '6 173 817  ₽ ',
#   'Тушинская',
#   'Москва, Волоколамское шоссе, 71к4',
#   'flat'],
#  ['1-к квартира',
#   ' 43 м²',
#   ' 4/8 эт.',
#   '12 650 000  ₽ ',
#   'Тушинская',
#   'Москва, Волоколамское шоссе, 71к3',
#   'flat'],
#  ['5-к квартира',
#   ' 141.9 м²',
#   ' 19/22 эт.',
#   '27 733 120  ₽ ',
#   'Тушинская',
#   'Волоколамское ш., д. 71/8',
#   'flat'],
#  ['5-к квартира',
#   ' 494.4 м²',
#   ' 33/35 эт.',
#   '180 000 000  ₽ ',
#   'Тушинская',
#   'Москва, Авиационная улица, 79с1',
#   'flat'],
#  ['6-к квартира',
#   ' 260 м²',
#   ' 1/5 эт.',
#   '99 900 000  ₽ ',
#   'Тушинская',
#   'Москва, Береговая улица',
#   'flat'],
#  ['1-к квартира',
#   ' 25.7 м²',
#   ' 4/13 эт.',
#   '7 080 350  ₽ ',
#   'Тушинская',
#   'ш. Волоколамское, корп. 10, вл. 71/13',
#   'flat'],
#  ['5-к квартира',
#   ' 205.7 м²',
#   ' 26/31 эт.',
#   '48 003 354  ₽ ',
#   'Тушинская',
#   'ул. Авиационная, д. 77, корп. 2',
#   'flat'],
#  ['1-к квартира',
#   ' 34.5 м²',
#   ' 10/13 эт.',
#   '8 825 100  ₽ ',
#   'Тушинская',
#   'ш. Волоколамское, корп. 10, вл. 71/13',
#   'flat'],
#  ['1-к квартира',
#   ' 38.6 м²',
#   ' 13/20 эт.',
#   '9 116 304  ₽ ',
#   'Тушинская',
#   'Волоколамское ш., вл. 71/8',
#   'flat'],
#  ['1-к квартира',
#   ' 38.6 м²',
#   ' 1/13 эт.',
#   '8 418 660  ₽ ',
#   'Тушинская',
#   'ш. Волоколамское, корп. 10, вл. 71/13',
#   'flat'],
#  ['2-к квартира',
#   ' 67 м²',
#   ' 8/20 эт.',
#   '13 362 525  ₽ ',
#   'Тушинская',
#   'Волоколамское ш., вл. 71/8',
#   'flat'],
#  ['1-к квартира',
#   ' 39.2 м²',
#   ' 2/20 эт.',
#   '8 108 455  ₽ ',
#   'Тушинская',
#   'Волоколамское ш., вл. 71/8',
#   'flat'],
#  ['3-к квартира',
#   ' 112.1 м²',
#   ' 14/22 эт.',
#   '21 751 625  ₽ ',
#   'Тушинская',
#   'Волоколамское ш., д. 71/8',
#   'flat'],
#  ['2-к квартира',
#   ' 53.4 м²',
#   ' 22/22 эт.',
#   '8 287 680  ₽ ',
#   'Тушинская',
#   'ш. Волоколамское, вл. 71/22',
#   'flat'],
#  ['2-к квартира',
#   ' 65.9 м²',
#   ' 22/22 эт.',
#   '15 483 118  ₽ ',
#   'Тушинская',
#   'Волоколамское ш., д. 71/8',
#   'flat'],
#  ['2-к квартира',
#   ' 51 м²',
#   ' 4/5 эт.',
#   '14 000 000  ₽ ',
#   'Тушинская',
#   'Москва, улица Маршала Василевского, 13к1',
#   'flat'],
#  ['3-к квартира',
#   ' 113 м²',
#   ' 2/22 эт.',
#   '19 093 351  ₽ ',
#   'Тушинская',
#   'Волоколамское ш., д. 71/8',
#   'flat'],
#  ['1-к квартира',
#   ' 26.4 м²',
#   ' 20/22 эт.',
#   '5 457 672  ₽ ',
#   'Тушинская',
#   'ш. Волоколамское, вл. 71/22',
#   'flat'],
#  ['5-к квартира',
#   ' 248.2 м²',
#   ' 5/32 эт.',
#   '40 549 643  ₽ ',
#   'Тушинская',
#   'ул. Авиационная, д. 77, корп. 2',
#   'flat'],
#  ['5-к квартира',
#   ' 494.4 м²',
#   ' 33/33 эт.',
#   '181 815 750  ₽ ',
#   'Тушинская',
#   'Москва, Авиационная улица, 77',
#   'flat'],
#  ['2-к квартира',
#   ' 51.9 м²',
#   ' 6/22 эт.',
#   '7 556 640  ₽ ',
#   'Тушинская',
#   'ш. Волоколамское, вл. 71/22',
#   'flat'],
#  ['1-к квартира',
#   ' 40.3 м²',
#   ' 4/20 эт.',
#   '8 570 125  ₽ ',
#   'Тушинская',
#   'ул. Летняя, вл. 95Б',
#   'flat'],
#  ['2-к квартира',
#   ' 72.3 м²',
#   ' 12/20 эт.',
#   '14 600 167  ₽ ',
#   'Тушинская',
#   'Волоколамское ш., вл. 71/8',
#   'flat'],
#  ['5-к квартира',
#   ' 221.4 м²',
#   ' 20/24 эт.',
#   '95 000 000  ₽ ',
#   'Тушинская',
#   'Москва, Иваньковское шоссе, 5',
#   'flat'],
#  ['8-к квартира',
#   ' 560 м²',
#   ' 4/33 эт.',
#   '180 000 000  ₽ ',
#   'Тушинская',
#   'Москва, Авиационная улица, 77',
#   'flat'],
#  ['4-к квартира',
#   ' 174 м²',
#   ' 3/6 эт.',
#   '115 000 000  ₽ ',
#   'Тушинская',
#   'Москва, Береговая улица, 4к10',
#   'flat'],
#  ['1-к квартира',
#   ' 40.1 м²',
#   ' 4/24 эт.',
#   '9 371 370  ₽ ',
#   'Тушинская',
#   'ш. Волоколамское, корп. 10, вл. 71/13',
#   'flat'],
#  ['1-к квартира',
#   ' 42.9 м²',
#   ' 4/20 эт.',
#   '8 400 000  ₽ ',
#   'Тушинская',
#   'Волоколамское ш., вл. 71/8',
#   'flat'],
#  ['2-к квартира',
#   ' 55.1 м²',
#   ' 5/22 эт.',
#   '8 050 110  ₽ ',
#   'Тушинская',
#   'ш. Волоколамское, вл. 71/22',
#   'flat'],
#  ['2-к квартира',
#   ' 116 м²',
#   ' 3/6 эт.',
#   '40 000 000  ₽ ',
#   'Тушинская',
#   'Береговая ул., 4к5',
#   'flat'],
#  ['3-к квартира',
#   ' 90.5 м²',
#   ' 8/20 эт.',
#   '17 184 370  ₽ ',
#   'Тушинская',
#   'Волоколамское ш., вл. 71/8',
#   'flat'],
#  ['3-к квартира',
#   ' 69.1 м²',
#   ' 21/22 эт.',
#   '9 730 662  ₽ ',
#   'Тушинская',
#   'ш. Волоколамское, вл. 71/22',
#   'flat'],
#  ['2-к квартира',
#   ' 54.9 м²',
#   ' 13/22 эт.',
#   '8 130 690  ₽ ',
#   'Тушинская',
#   'ш. Волоколамское, вл. 71/22',
#   'flat'],
#  ['5-к квартира',
#   ' 206.4 м²',
#   ' 3/17 эт.',
#   '48 500 000  ₽ ',
#   'Тушинская',
#   'Москва, улица Маршала Василевского, 13к3',
#   'flat'],
#  ['3-к квартира',
#   ' 93 м²',
#   ' 4/19 эт.',
#   '19 400 000  ₽ ',
#   'Тушинская',
#   'Москва, Волоколамское шоссе, 71к2',
#   'flat'],
#  ['5-к квартира',
#   ' 176 м²',
#   ' 3/32 эт.',
#   '65 000 000  ₽ ',
#   'Тушинская',
#   'Москва, Авиационная улица, 77',
#   'flat'],
#  ['1-к квартира',
#   ' 38.7 м²',
#   ' 2/20 эт.',
#   '7 200 000  ₽ ',
#   'Тушинская',
#   'Волоколамское ш., вл. 71/8',
#   'flat'],
#  ['5-к квартира',
#   ' 230 м²',
#   ' 1/3 эт.',
#   '135 000 000  ₽ ',
#   'Тушинская',
#   'Москва, Ленинградское шоссе, 23к3с5',
#   'flat'],
#  ['3-к квартира',
#   ' 73.2 м²',
#   ' 21/22 эт.',
#   '10 264 104  ₽ ',
#   'Тушинская',
#   'ш. Волоколамское, вл. 71/22',
#   'flat'],
#  ['3-к квартира',
#   ' 108 м²',
#   ' 4/17 эт.',
#   '33 900 000  ₽ ',
#   'Тушинская',
#   'Москва, улица Маршала Василевского, 13к3',
#   'flat'],
#  ['6-к квартира',
#   ' 200 м²',
#   ' 2/6 эт.',
#   '120 000 000  ₽ ',
#   'Тушинская',
#   'Москва, Береговая улица, 4к3',
#   'flat'],
#  ['1-к квартира',
#   ' 43.1 м²',
#   ' 4/8 эт.',
#   '12 500 000  ₽ ',
#   'Тушинская',
#   'Волоколамское ш., вл. 71/9',
#   'flat'],
#  ['2-к квартира',
#   ' 51.7 м²',
#   ' 9/22 эт.',
#   '7 687 790  ₽ ',
#   'Тушинская',
#   'ш. Волоколамское, вл. 71/22',
#   'flat'],
#  ['5-к квартира',
#   ' 141.9 м²',
#   ' 12/22 эт.',
#   '21 600 000  ₽ ',
#   'Тушинская',
#   'Волоколамское ш., жилые дома',
#   'flat'],
#  ['1-к квартира',
#   ' 37.7 м²',
#   ' 10/20 эт.',
#   '7 900 000  ₽ ',
#   'Тушинская',
#   'Волоколамское ш., вл. 71/8',
#   'flat'],
#  ['1-к квартира',
#   ' 31.8 м²',
#   ' 5/22 эт.',
#   '6 148 000  ₽ ',
#   'Тушинская',
#   'Волоколамское ш., вл. 71/9',
#   'flat'],
#  ['7-к квартира',
#   ' 613 м²',
#   ' 23/23 эт.',
#   '421 812 540  ₽ ',
#   'Тушинская',
#   'Москва, Иваньковское шоссе, 5',
#   'flat'],
#  ['3-к квартира',
#   ' 93.7 м²',
#   ' 6/20 эт.',
#   '17 700 000  ₽ ',
#   'Тушинская',
#   'Волоколамское ш., вл. 71/8',
#   'flat'],
#  ['3-к квартира',
#   ' 100.2 м²',
#   ' 28/28 эт.',
#   '34 800 000  ₽ ',
#   'Тушинская',
#   'ул. Маршала Катукова, 24к3',
#   'flat'],
#  ['2-к квартира',
#   ' 53 м²',
#   ' 12/12 эт.',
#   '8 550 000  ₽ ',
#   'Тушинская',
#   'пр. Досфлота, 3',
#   'flat'],
#  ['5-к квартира',
#   ' 141.9 м²',
#   ' 14/22 эт.',
#   '27 032 660  ₽ ',
#   'Тушинская',
#   'Волоколамское ш., вл. 71/9',
#   'flat'],
#  ['2-к квартира',
#   ' 41 м²',
#   ' 4/5 эт.',
#   '7 500 000  ₽ ',
#   'Тушинская',
#   'б-р Яна Райниса, 3',
#   'flat'],
#  ['5-к квартира',
#   ' 141.9 м²',
#   ' 18/22 эт.',
#   '27 437 749  ₽ ',
#   'Тушинская',
#   'Волоколамское ш., вл. 71/9',
#   'flat'],
#  ['3-к квартира',
#   ' 105.8 м²',
#   ' 15/20 эт.',
#   '20 949 330  ₽ ',
#   'Тушинская',
#   'Волоколамское ш., вл. 71/8',
#   'flat'],
#  ['1-к квартира',
#   ' 13.4 м²',
#   ' 4/5 эт.',
#   '6 000 000  ₽ ',
#   'Тушинская',
#   'Химкинский б-р, 19к1',
#   'flat'],
#  ['5-к квартира',
#   ' 141.9 м²',
#   ' 19/22 эт.',
#   '31 200 000  ₽ ',
#   'Тушинская',
#   'Северо-Западный административный округ, район Покровское-Стрешнево',
#   'flat'],
#  ['1-к квартира',
#   ' 39 м²',
#   ' 12/12 эт.',
#   '8 500 000  ₽ ',
#   'Тушинская',
#   'б-р Яна Райниса, д. 4, корп. 3',
#   'flat'],
#  ['1-к квартира',
#   ' 37 м²',
#   ' 4/16 эт.',
#   '7 100 000  ₽ ',
#   'Тушинская',
#   'Аэродромная ул., 1',
#   'flat'],
#  ['1-к квартира',
#   ' 39 м²',
#   ' 7/20 эт.',
#   '8 015 000  ₽ ',
#   'Тушинская',
#   'Волоколамское ш., 71к3',
#   'flat'],
#  ['3-к квартира',
#   ' 69.1 м²',
#   ' 19/22 эт.',
#   '9 385 162  ₽ ',
#   'Тушинская',
#   'Москва, Волоколамское шоссе, 71к4',
#   'flat'],
#  ['2-к квартира',
#   ' 65.6 м²',
#   ' 19/22 эт.',
#   '14 474 578  ₽ ',
#   'Тушинская',
#   'Волоколамское ш., вл. 71/9',
#   'flat'],
#  ['9-к квартира',
#   ' 1500 м²',
#   ' 1/2 эт.',
#   '267 000 000  ₽ ',
#   'Тушинская',
#   'Северо-Западный административный округ, район Покровское-Стрешнево',
#   'flat'],
#  ['1-к квартира',
#   ' 39 м²',
#   ' 1/12 эт.',
#   '6 700 000  ₽ ',
#   'Тушинская',
#   'б-р Яна Райниса, 14к2',
#   'flat'],
#  ['2-к квартира',
#   ' 111 м²',
#   ' 4/6 эт.',
#   '32 000 000  ₽ ',
#   'Тушинская',
#   'Береговая ул., 4к5',
#   'flat']]

# %%
def write_db(connect, port, db, coll, advert_list):
    conn = pymongo.MongoClient(connect, port, username='admin', password='12345',authSource='avito_parse_data', authMechanism='SCRAM-SHA-1')#username='user',password='password',
    db = conn[db]
    coll = db[coll]
    coll.remove({"property_type": advert_list[0][6]})
    for i in advert_list:
        doc = {"rooms_number": i[0],
               "footage": i[1],
               "floor": i[2],
               "price": i[3],
               "metro": i[4],
               "address": i[5],
               "property_type": i[6]
               }
        coll.save(doc)

# %%
write_db(db_address, db_port, db_name, coll_name, advert)
# Out:
# C:\Users\Anton\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: remove is deprecated. Use delete_one or delete_many instead.
#   """
# C:\Users\Anton\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: save is deprecated. Use insert_one or replace_one instead
#   from ipykernel import kernelapp as app

# %%
def salary_calc_avg(connect, port, db, coll,search_value):
    conn = pymongo.MongoClient(connect, port)
    db = conn[db]
    coll = db[coll]
    avg_salary = 0
    count = 0

    for item in coll.find({"_search_parr": search_value}):
       # print(re.sub("[^-0-9]", "", item["_salary"]).split('-'))
        avg_el = re.sub("[^-0-9]", "", item["_salary"]).split('-')
        if len(avg_el) == 2:
            avg_salary = (int(avg_el[0] or 0) + int(avg_el[1] or 0))/2 + int(avg_salary)
        else:
            avg_salary = int(avg_el[0] or 0) + int(avg_salary)
        if int(re.sub("[^0-9]", "", item["_salary"]) or 0) > 0:
            count = count + 1
   # print(avg_salary/count)
    #print(count)
    if count == 0:
        return 0
    else:
        return avg_salary/count

exit_flag = False
flag_country = False
flag_prof = False
flag_period = False

print('Вас приветствует программа для подсчёта среднего уровня зарплаты для введенной должности')
while (not exit_flag):
    if not flag_country:
        print('Введите номер региона вашего проживания (Пермский край - 1317):')
        search_area = input() #'1317'
    if not flag_prof:
        print('Введите наименование должности (или ключевое слово для поиска набора профессий):')
        search_value = input()# 'python'
    if not flag_period:
        print('Введите период, за который хотите получить информацию (одно число):')
        search_period = input() #'30'
    url_base = 'https://perm.hh.ru/'
    url = url_base + 'search/vacancy?area=' + search_area + '&clusters=true&enable_snippets=true&search_period=' + search_period + '&text=' + search_value + '&page=0'  # area=1317 - Пермский край, search_period=30 - период просмотра, page=0 - Номер страницы
    jobs = []

    jobs = hhru_parse(url, headers, search_value)
    print('Данные успешно скачаны')
    hhru_write_db(db_address, db_port, db_name, coll_name, jobs)
    print('Данные успешно обновлены в БД')
    print('Средняя заработная плата по вашему поисковому запросу: ' + str(salary_calc_avg(db_address, db_port, db_name, coll_name, search_value)))
    print('Вы хотите выполнить поиск по другой профессии? Y/N')
    q1 = input()
    if q1 == 'Y':
        flag_country = True
        flag_period = True
    else:
        print('Вы хотите выполнить поиск по всем новым параметрам? Y/N')
        q2 = input()
        if q2 == 'Y':
            flag_country = False
            flag_country = False
        else:
            exit_flag = True
    print('Работа с программой завершена')
